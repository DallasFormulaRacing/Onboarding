# %%
import plotly.express as px

import pandas as pd

csv = "datadump.csv"
df = pd.read_csv(csv)

x = [f"Analog Input #{x}" for x in range(3,9)]

# print(x)
print(df.drop(x, axis = 1))

RPM = df["RPM"].tolist()
TPS = df["TPS"].tolist()
RPM_GRAPH = px.line(RPM) 
TPS_GRAPH = px.line(TPS)

 
# printing the figure instance
RPM_GRAPH.show()
TPS_GRAPH.show()
# Out:
#           timestamp  Analog Input #1  Analog Input #2  Frequency 1  \
# 0      1.721154e+09             1.52             2.05          NaN
# 1      1.721154e+09             1.52             2.05          NaN
# 2      1.721154e+09             1.52             2.05          0.0
# 3      1.721154e+09             1.52             2.05          0.0
# 4      1.721154e+09             1.52             2.05          0.0
# ...             ...              ...              ...          ...
# 14367  1.721154e+09             1.50             2.22          0.0
# 14368  1.721154e+09             1.50             2.22          0.0
# 14369  1.721154e+09             1.51             2.22          0.0
# 14370  1.721154e+09             1.51             2.22          0.0
# 14371  1.721154e+09             1.51             2.22          0.0
#
#        Frequency 2  Frequency 3  Frequency 4  Driven Avg Wheel Speed  \
# 0              NaN          NaN          NaN                     NaN
# 1              NaN          NaN          NaN                     NaN
# 2              0.0          0.0          0.0                     NaN
# 3              0.0          0.0          0.0                     0.0
# 4              0.0          0.0          0.0                     0.0
# ...            ...          ...          ...                     ...
# 14367          0.0          0.0          0.0                     0.0
# 14368          0.0          0.0          0.0                     0.0
# 14369          0.0          0.0          0.0                     0.0
# 14370          0.0          0.0          0.0                     0.0
# 14371          0.0          0.0          0.0                     0.0
#
#        Non-Driven Avg Wheel Speed  Ignition Compensation  ...  \
# 0                             NaN                    NaN  ...
# 1                             NaN                    NaN  ...
# 2                             NaN                    NaN  ...
# 3                             0.0                    0.0  ...
# 4                             0.0                    0.0  ...
# ...                           ...                    ...  ...
# 14367                         0.0                    0.0  ...
# 14368                         0.0                    0.0  ...
# 14369                         0.0                    0.0  ...
# 14370                         0.0                    0.0  ...
# 14371                         0.0                    0.0  ...
#
#        Non-Driven Wheel Speed #1  Non-Driven Wheel Speed #2  Barometer    MAP  \
# 0                            NaN                        NaN        NaN    NaN
# 1                            NaN                        NaN        NaN    NaN
# 2                            NaN                        NaN        NaN    NaN
# 3                            NaN                        NaN        NaN    NaN
# 4                            NaN                        NaN        NaN    NaN
# ...                          ...                        ...        ...    ...
# 14367                        0.0                        0.0       14.7  12.71
# 14368                        0.0                        0.0       14.7  12.55
# 14369                        0.0                        0.0       14.7  12.55
# 14370                        0.0                        0.0       14.7  12.55
# 14371                        0.0                        0.0       14.7  12.55
#
#        Lambda  Pressure Type  Battery Volt  Air Temp  Coolant Temp  Temp Type
# 0         NaN            NaN           NaN       NaN           NaN        NaN
# 1         NaN            NaN           NaN       NaN           NaN        NaN
# 2         NaN            NaN           NaN       NaN           NaN        NaN
# 3         NaN            NaN           NaN       NaN           NaN        NaN
# 4         NaN            NaN           NaN       NaN           NaN        NaN
# ...       ...            ...           ...       ...           ...        ...
# 14367    0.98            KPA          14.2     106.0         199.6          C
# 14368    0.98            KPA          14.2     106.0         199.6          C
# 14369    0.98            KPA          14.2     106.0         199.6          C
# 14370    0.98            KPA          14.2     106.0         199.6          C
# 14371    0.98            KPA          14.2     106.0         199.6          C
#
# [14372 rows x 27 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 20
#      16 TPS_GRAPH = px.line(TPS)
#      19 # printing the figure instance
# ---> 20 RPM_GRAPH.show()
#      21 TPS_GRAPH.show()
#
# File ~/Git Repos/Onboarding/.venv/lib/python3.11/site-packages/plotly/basedatatypes.py:3414, in BaseFigure.show(self, *args, **kwargs)
#    3381 """
#    3382 Show a figure using either the default renderer(s) or the renderer(s)
#    3383 specified by the renderer argument
#    (...)
#    3410 None
#    3411 """
#    3412 import plotly.io as pio
# -> 3414 return pio.show(self, *args, **kwargs)
#
# File ~/Git Repos/Onboarding/.venv/lib/python3.11/site-packages/plotly/io/_renderers.py:425, in show(fig, renderer, validate, **kwargs)
#     420     raise ValueError(
#     421         "Mime type rendering requires ipython but it is not installed"
#     422     )
#     424 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 425     raise ValueError(
#     426         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     427     )
#     429 display_jupyter_version_warnings()
#     431 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed
