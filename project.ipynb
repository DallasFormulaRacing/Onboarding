# %%
import pandas as pd
import plotly.express as px

df = pd.read_csv('can_data.csv')

# %%
# print(df)
# print(len(df.columns))
# Out:
#           timestamp  Analog Input #1  Analog Input #2  Analog Input #3  \
# 0      1.721154e+09             1.52             2.05             0.01
# 1      1.721154e+09             1.52             2.05             0.01
# 2      1.721154e+09             1.52             2.05             0.01
# 3      1.721154e+09             1.52             2.05             0.01
# 4      1.721154e+09             1.52             2.05             0.01
# ...             ...              ...              ...              ...
# 14367  1.721154e+09             1.50             2.22             0.01
# 14368  1.721154e+09             1.50             2.22             0.01
# 14369  1.721154e+09             1.51             2.22             0.01
# 14370  1.721154e+09             1.51             2.22             0.01
# 14371  1.721154e+09             1.51             2.22             0.01
#
#        Analog Input #4  Analog Input #5  Analog Input #6  Analog Input #7  \
# 0                 0.52              NaN              NaN              NaN
# 1                 0.52             0.01             0.71             0.01
# 2                 0.52             0.01             0.71             0.01
# 3                 0.52             0.01             0.71             0.01
# 4                 0.52             0.01             0.71             0.01
# ...                ...              ...              ...              ...
# 14367             0.51             0.01             0.57             0.01
# 14368             0.51             0.01             0.57             0.01
# 14369             0.51             0.01             0.57             0.01
# 14370             0.51             0.01             0.57             0.01
# 14371             0.51             0.01             0.57             0.01
#
#        Analog Input #8  Frequency 1  ...  Non-Driven Wheel Speed #1  \
# 0                  NaN          NaN  ...                        NaN
# 1                 0.04          NaN  ...                        NaN
# 2                 0.04          0.0  ...                        NaN
# 3                 0.04          0.0  ...                        NaN
# 4                 0.04          0.0  ...                        NaN
# ...                ...          ...  ...                        ...
# 14367             0.04          0.0  ...                        0.0
# 14368             0.04          0.0  ...                        0.0
# 14369             0.04          0.0  ...                        0.0
# 14370             0.04          0.0  ...                        0.0
# 14371             0.04          0.0  ...                        0.0
#
#        Non-Driven Wheel Speed #2  Barometer    MAP  Lambda  Pressure Type  \
# 0                            NaN        NaN    NaN     NaN            NaN
# 1                            NaN        NaN    NaN     NaN            NaN
# 2                            NaN        NaN    NaN     NaN            NaN
# 3                            NaN        NaN    NaN     NaN            NaN
# 4                            NaN        NaN    NaN     NaN            NaN
# ...                          ...        ...    ...     ...            ...
# 14367                        0.0       14.7  12.71    0.98            KPA
# 14368                        0.0       14.7  12.55    0.98            KPA
# 14369                        0.0       14.7  12.55    0.98            KPA
# 14370                        0.0       14.7  12.55    0.98            KPA
# 14371                        0.0       14.7  12.55    0.98            KPA
#
#        Battery Volt  Air Temp  Coolant Temp  Temp Type
# 0               NaN       NaN           NaN        NaN
# 1               NaN       NaN           NaN        NaN
# 2               NaN       NaN           NaN        NaN
# 3               NaN       NaN           NaN        NaN
# 4               NaN       NaN           NaN        NaN
# ...             ...       ...           ...        ...
# 14367          14.2     106.0         199.6          C
# 14368          14.2     106.0         199.6          C
# 14369          14.2     106.0         199.6          C
# 14370          14.2     106.0         199.6          C
# 14371          14.2     106.0         199.6          C
#
# [14372 rows x 33 columns]
# 33

# %%
for col in df.columns:
    if col.startswith("Analog Input") and df[col].nunique() <= 1:
        df = df.drop(columns=[col])
print(df)
# Out:
#           timestamp  Analog Input #1  Analog Input #2  Analog Input #4  \
# 0      1.721154e+09             1.52             2.05             0.52
# 1      1.721154e+09             1.52             2.05             0.52
# 2      1.721154e+09             1.52             2.05             0.52
# 3      1.721154e+09             1.52             2.05             0.52
# 4      1.721154e+09             1.52             2.05             0.52
# ...             ...              ...              ...              ...
# 14367  1.721154e+09             1.50             2.22             0.51
# 14368  1.721154e+09             1.50             2.22             0.51
# 14369  1.721154e+09             1.51             2.22             0.51
# 14370  1.721154e+09             1.51             2.22             0.51
# 14371  1.721154e+09             1.51             2.22             0.51
#
#        Analog Input #6  Frequency 1  Frequency 2  Frequency 3  Frequency 4  \
# 0                  NaN          NaN          NaN          NaN          NaN
# 1                 0.71          NaN          NaN          NaN          NaN
# 2                 0.71          0.0          0.0          0.0          0.0
# 3                 0.71          0.0          0.0          0.0          0.0
# 4                 0.71          0.0          0.0          0.0          0.0
# ...                ...          ...          ...          ...          ...
# 14367             0.57          0.0          0.0          0.0          0.0
# 14368             0.57          0.0          0.0          0.0          0.0
# 14369             0.57          0.0          0.0          0.0          0.0
# 14370             0.57          0.0          0.0          0.0          0.0
# 14371             0.57          0.0          0.0          0.0          0.0
#
#        Driven Avg Wheel Speed  ...  Non-Driven Wheel Speed #1  \
# 0                         NaN  ...                        NaN
# 1                         NaN  ...                        NaN
# 2                         NaN  ...                        NaN
# 3                         0.0  ...                        NaN
# 4                         0.0  ...                        NaN
# ...                       ...  ...                        ...
# 14367                     0.0  ...                        0.0
# 14368                     0.0  ...                        0.0
# 14369                     0.0  ...                        0.0
# 14370                     0.0  ...                        0.0
# 14371                     0.0  ...                        0.0
#
#        Non-Driven Wheel Speed #2  Barometer    MAP  Lambda  Pressure Type  \
# 0                            NaN        NaN    NaN     NaN            NaN
# 1                            NaN        NaN    NaN     NaN            NaN
# 2                            NaN        NaN    NaN     NaN            NaN
# 3                            NaN        NaN    NaN     NaN            NaN
# 4                            NaN        NaN    NaN     NaN            NaN
# ...                          ...        ...    ...     ...            ...
# 14367                        0.0       14.7  12.71    0.98            KPA
# 14368                        0.0       14.7  12.55    0.98            KPA
# 14369                        0.0       14.7  12.55    0.98            KPA
# 14370                        0.0       14.7  12.55    0.98            KPA
# 14371                        0.0       14.7  12.55    0.98            KPA
#
#        Battery Volt  Air Temp  Coolant Temp  Temp Type
# 0               NaN       NaN           NaN        NaN
# 1               NaN       NaN           NaN        NaN
# 2               NaN       NaN           NaN        NaN
# 3               NaN       NaN           NaN        NaN
# 4               NaN       NaN           NaN        NaN
# ...             ...       ...           ...        ...
# 14367          14.2     106.0         199.6          C
# 14368          14.2     106.0         199.6          C
# 14369          14.2     106.0         199.6          C
# 14370          14.2     106.0         199.6          C
# 14371          14.2     106.0         199.6          C
#
# [14372 rows x 29 columns]

# %%
df.columns
# Out:
# Index(['timestamp', 'Analog Input #1', 'Analog Input #2', 'Analog Input #4',
#        'Analog Input #6', 'Frequency 1', 'Frequency 2', 'Frequency 3',
#        'Frequency 4', 'Driven Avg Wheel Speed', 'Non-Driven Avg Wheel Speed',
#        'Ignition Compensation', 'Ignition Cut Percentage', 'RPM', 'TPS',
#        'Fuel Open Time', 'Ignition Angle', 'Driven Wheel Speed #1',
#        'Driven Wheel Speed #2', 'Non-Driven Wheel Speed #1',
#        'Non-Driven Wheel Speed #2', 'Barometer', 'MAP', 'Lambda',
#        'Pressure Type', 'Battery Volt', 'Air Temp', 'Coolant Temp',
#        'Temp Type'],
#       dtype='object')

# %%
fig = px.line(df, x='timestamp', y='RPM', title='Change In RPM Over Time')
fig_2 = px.line(df, x='timestamp', y='TPS', title='Change In TPS Over Time')
fig.update_layout(xaxis_title="Time", yaxis_title="RPM")
fig_2.update_layout(xaxis_title="Time", yaxis_title="TPS (%)")
fig.show()
fig_2.show()
